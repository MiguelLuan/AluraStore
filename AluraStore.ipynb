# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelLuan/AluraStore/blob/main/AluraStore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🚀 CONFIGURAÇÃO INICIAL
from getpass import getpass
import os

# 1️⃣ Token do GitHub (digite uma vez por sessão)
token = getpass('Digite seu token do GitHub: ')
repo_url = f"https://{token}@github.com/MiguelLuan/AluraStore.git"

# 2️⃣ Clonar repositório e entrar na pasta
# !rm -rf AluraStore
# !git clone {repo_url}
# %cd AluraStore

# 3️⃣ Configuração do Git
# !git config --global user.email "miguelcurseiro1000@gmail.com"
# !git config --global user.name "MiguelLuan"

# !git push origin main
# Out:
# Digite seu token do GitHub: ··········
# Cloning into 'AluraStore'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 14 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 224.48 KiB | 5.61 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# /content/AluraStore

# %%
# Out:
# Everything up-to-date
